# %% [markdown]
# ## Images in your Markdown cells

# %% [markdown]
# #### An image from the web:
# This can be difficult to work with and not render on GitHub (even if rendered on your Notebook) because of various permissions set up on the server hosting the image. Not all servers allow GitHub to make calls for a linked image automatically.
#
# ![StreetTriple](https://imgd.aeplcdn.com/664x374/n/cw/ec/137433/street-triple-rs-right-side-view-3.png)

# %% [markdown]
# #### An image from your computer:
# This will render in your Notebook, but requires an additional step for the image to be included when you upload your notebook to GitHub.
# ##### This image shows in the Notebook, but not GitHub:
# ![StreetTriple](street-triple-rs-right-side-view-5.jpg)
#
# ##### This image shows in the Notebook and in GitHub:
# This works becasue the image has been included as an `attachment` to the Notebook file. This makes your .ipynb file larger because it also includes the data for the image, but it will render correctly on GitHub and other places on the web. Instead of using Markdown syntax, this reqiures you to drag and drop the image from your computer to the Markdown cell.
# The full Markdown syntax is: `![street-triple-rs-rftq.jpg](attachment:3d4809ac-6eb4-400a-9bf7-cb3aa66b5227.jpg)`
# The name '3d4809ac-6eb4-400a-9bf7-cb3aa66b5227.jpg' for the image is generated by the Notebook.
# ![street-triple-rs-rftq.jpg](attachment:3d4809ac-6eb4-400a-9bf7-cb3aa66b5227.jpg)
