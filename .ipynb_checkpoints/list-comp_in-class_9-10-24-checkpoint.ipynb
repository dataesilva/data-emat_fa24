# %%
import pandas as pd
import json

# %%
path = r"C:\Users\dsilva2\OneDrive - Kent State University\Research_KSU_Share\SocMed-Personal-Data\facebook-davidsilva100046-16_08_2024-0ZtJc3p1\your_facebook_activity\messages\inbox\chessbuds_3243775372391981\chessbuds_message_1.json"
with open(path) as j:
    mess = json.load(j)

# %%
mess.keys()

# %%
mess_df = pd.DataFrame(mess['messages'])
mess_df.head()

# %%
my_list = ['0','1','2','3','4']
new_list = [print(x+'David') for x in my_list]

# %%
new_list

# %%
mess_df['pretty_sender_name'] = ['Sender is: '+x for x in mess_df['sender_name']]
mess_df.head()
# Out:
#             sender_name   timestamp_ms  \
# 0           Scott Pence  1700715443482
# 1           Scott Pence  1700612654330
# 2           Scott Pence  1692288525908
# 3  Angela Babbitt Pence  1692288480858
# 4          Joanna Rusch  1692253364213
#
#                                               photos  \
# 0  [{'uri': 'your_facebook_activity/messages/inbo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    is_geoblocked_for_viewer  \
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
#                                              content  \
# 0                                                NaN
# 1   https://youtu.be/QvhD801swLI?si=QbdZsCAZaYo0FXp_
# 2                                                NaN
# ...

# %%
mess_df['reactions'].iloc[2][0]['actor']
# Out:
# 'Joanna Rusch'

# %%
mess_df['reactions'][2:4]
# Out:
# 2    [{'reaction': 'ð', 'actor': 'Joanna Rusch'}...
# 3      [{'reaction': 'ð', 'actor': 'Joanna Rusch'}]
# Name: reactions, dtype: object

# %%
[x[0]['actor'] for x in mess_df['reactions'][2:4]]
# Out:
# ['Joanna Rusch', 'Joanna Rusch']

# %%
[x[0]['actor'] for x in mess_df['reactions']]

# %%
[x[0]['actor'] if isinstance(x, list) else ''\
 for x in mess_df['reactions']]
# Out:
# ['',
#  '',
#  'Joanna Rusch',
#  'Joanna Rusch',
#  '',
#  'Angela Babbitt Pence',
#  'Chad Larson',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  'Chad Larson',
#  '',
#  'Chad Larson',
#  '',
#  '',
#  '',
#  'Joanna Rusch',
#  '',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  'Chad Larson',
#  'Joanna Rusch',
#  'Chad Larson',
#  'Scott Pence',
#  'Scott Pence',
#  'Chad Larson',
#  '',
#  'Chad Larson',
#  'Joanna Rusch',
#  '',
#  'Joanna Rusch',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Chad Larson',
#  '',
#  '',
#  '',
#  'Chad Larson',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
isinstance(my_list, list)
# Out:
# True

# %%
ces = pd.read_csv('cces_example_data.csv')
ces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
ces.shape
# Out:
# (659, 21)

# %%
ces[ces['age'] > 35]

# %%
ces[ces['sex'] == 2]

# %%
ces[(ces['sex'] == 2) & (ces['age'] > 35)]

# %%
ces.query('sex == 2 & age > 35')

# %%
ces.query('age < 40 & nonwhite == 1 & ideo5 < 3 & ConMediaUse > 3')
# Out:
#      pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 229             4            6    2     4         1   38           9     1
# 307             4            6    2     6         1   33          14     3
# 315             2            3    1     6         1   31          11     3
# 372             1            4    1     4         1   35           9     1
# 408             4            5    2     5         1   38          10     3
# 601             2            3    2     5         1   24           5     3
# 656             4            6    1     3         1   20           7     1
#
#      ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 229      2     3.000000  ...              -71             -82            -75
# 307      2     1.666667  ...              -69             -76            -82
# 315      2     4.000000  ...               18             -11             22
# ...

# %%
ces[(ces['age'] < 40) & (ces['nonwhite'] == 1) & (ces['ideo5'] < 3) & (ces['ConMediaUse'] >3)]
# Out:
#      pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 229             4            6    2     4         1   38           9     1
# 307             4            6    2     6         1   33          14     3
# 315             2            3    1     6         1   31          11     3
# 372             1            4    1     4         1   35           9     1
# 408             4            5    2     5         1   38          10     3
# 601             2            3    2     5         1   24           5     3
# 656             4            6    1     3         1   20           7     1
#
#      ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 229      2     3.000000  ...              -71             -82            -75
# 307      2     1.666667  ...              -69             -76            -82
# 315      2     4.000000  ...               18             -11             22
# ...

# %%
[', '.join([y['actor'] for y in x])\
 if isinstance(x, list) else ''\
 for x in mess_df['reactions']]
# Out:
# ['',
#  '',
#  'Joanna Rusch, Chad Larson',
#  'Joanna Rusch',
#  '',
#  'Angela Babbitt Pence, David Silva',
#  'Chad Larson, Joanna Rusch, David Silva',
#  '',
#  '',
#  '',
#  'Scott Pence, Chad Larson',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  'Chad Larson, Joanna Rusch',
#  '',
#  'Chad Larson, Joanna Rusch',
#  '',
#  '',
#  '',
#  'Joanna Rusch, Scott Pence',
#  '',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Joanna Rusch',
#  '',
#  '',
#  '',
#  'Scott Pence',
#  'Scott Pence, Angela Babbitt Pence',
#  '',
#  '',
#  '',
#  'Chad Larson, Scott Pence',
#  'Joanna Rusch',
#  'Chad Larson',
#  'Scott Pence',
#  'Scott Pence',
#  'Chad Larson',
#  '',
#  'Chad Larson',
#  'Joanna Rusch',
#  '',
#  'Joanna Rusch, Chad Larson',
#  'Joanna Rusch, Chad Larson',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Chad Larson, Scott Pence',
#  '',
#  '',
#  '',
# ...
