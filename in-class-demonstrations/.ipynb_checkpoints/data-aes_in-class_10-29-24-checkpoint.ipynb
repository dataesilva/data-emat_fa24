# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ad = pd.read_csv('../audio-features-analysis.csv')
ad.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.188   0.489    2   -10.152     1       0.0378
# 1           1         0.258   0.307    7   -10.207     1       0.0688
# 2           2         0.770   0.736    8    -4.980     0       0.0569
# 3           3         0.483   0.764    9    -4.897     1       0.0453
# 4           4         0.761   0.854   11    -3.405     0       0.0521
#
#    acousticness  instrumentalness  liveness  ...  \
# 0       0.76100           0.10300     0.109  ...
# 1       0.13000           0.00291     0.102  ...
# 2       0.06210           0.00843     0.109  ...
# 3       0.03800           0.13700     0.350  ...
# 4       0.00438           0.00615     0.315  ...
#
#                                                 href  is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/5tuHiLI7CPV1...     False        True
# 1  https://api.spotify.com/v1/tracks/5iI1svWkerLI...     False        True
# ...

# %%
ad.keys()
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type_x', 'id', 'uri_x', 'track_href',
#        'analysis_url', 'duration_ms_x', 'time_signature', 'album', 'artists',
#        'disc_number', 'duration_ms_y', 'explicit', 'external_ids',
#        'external_urls', 'href', 'is_local', 'is_playable', 'name',
#        'popularity', 'preview_url', 'track_number', 'type_y', 'uri_y',
#        'artist-album'],
#       dtype='object')

# %%
ad.columns
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type_x', 'id', 'uri_x', 'track_href',
#        'analysis_url', 'duration_ms_x', 'time_signature', 'album', 'artists',
#        'disc_number', 'duration_ms_y', 'explicit', 'external_ids',
#        'external_urls', 'href', 'is_local', 'is_playable', 'name',
#        'popularity', 'preview_url', 'track_number', 'type_y', 'uri_y',
#        'artist-album'],
#       dtype='object')

# %%
ad.shape
# Out:
# (22, 36)

# %%
ad.groupby('artist-album')['id'].count()
# Out:
# artist-album
# Phantogram: Memory of A Day        12
# St. Vincent: All Born Screaming    10
# Name: id, dtype: int64

# %%
fig1, ax1 = plt.subplots()
ax1.hist(ad['danceability'], bins = 6)

plt.show()

# %%
fig2, ax2 = plt.subplots(2, 3)
ax2[0,0].hist(ad['danceability'], bins = 5)
ax2[0, 1].hist(ad['energy'], bins = 5)
ax2[0,2].hist(ad['acousticness'], bins = 5)
ax2[1,0].hist(ad['instrumentalness'], bins = 5)
ax2[1,1].hist(ad['valence'], bins = 5)
ax2[1,2].hist(ad['liveness'], bins = 5)

plt.show()

# %%
ad[ad['liveness'] > .35][['name', 'artist-album']]
# Out:
#             name                 artist-album
# 10      Jealousy  Phantogram: Memory of A Day
# 16  I Wanna Know  Phantogram: Memory of A Day
# 20   Happy Again  Phantogram: Memory of A Day

# %%
ad[ad['instrumentalness'] > .5][['name', 'artist-album']]
# Out:
#             name                 artist-album
# 10      Jealousy  Phantogram: Memory of A Day
# 16  I Wanna Know  Phantogram: Memory of A Day

# %%
fig3, ax3 = plt.subplots(1, 3, figsize = (8, 2))
ax3[0].scatter(ad['danceability'], ad['energy'])
ax3[1].scatter(ad['danceability'], ad['valence'])
ax3[2].scatter(ad['energy'], ad['valence'])
# ax3[2].axline((0, .2), .1)

plt.show()

# %%
ad[ad['artist-album'] == 'Phantogram: Memory of A Day']
# Out:
#     Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 10           0         0.408   0.928    6    -5.208     0       0.0568
# 11           1         0.503   0.757    0    -6.163     1       0.0521
# 12           2         0.293   0.664    2    -6.427     1       0.0309
# 13           3         0.688   0.793    2    -5.031     1       0.0392
# 14           4         0.520   0.782    5    -8.134     0       0.0457
# 15           5         0.582   0.743    2    -6.728     1       0.0443
# 16           6         0.520   0.464    7    -6.578     1       0.0264
# 17           7         0.496   0.676    0    -7.440     1       0.0332
# 18           8         0.502   0.808    2    -5.494     0       0.0316
# 19           9         0.445   0.754    4    -5.052     0       0.0463
# 20          10         0.568   0.812    2    -4.801     1       0.0394
# 21          11         0.396   0.546    4    -8.655     1       0.0268
#
# ...

# %%
phanto = ad[ad['artist-album'] == 'Phantogram: Memory of A Day']
stv = ad[ad['artist-album'] == 'St. Vincent: All Born Screaming']

fi4, ax4 = plt.subplots()
ax4.scatter(phanto['energy'], phanto['valence'], color = 'red')
ax4.scatter(stv['energy'], stv['valence'], color = 'gray')
plt.show()

# %%
phanto = ad[ad['artist-album'] == 'Phantogram: Memory of A Day']
stv = ad[ad['artist-album'] == 'St. Vincent: All Born Screaming']

fi4, ax4 = plt.subplots()
ax4.scatter(phanto['danceability'], phanto['valence'], color = 'red')
ax4.scatter(stv['danceability'], stv['valence'], color = 'gray')
plt.show()

# %%
phanto = ad[ad['artist-album'] == 'Phantogram: Memory of A Day']
stv = ad[ad['artist-album'] == 'St. Vincent: All Born Screaming']


fig4, ax4 = plt.subplots()
phanto_scatter = ax4.scatter(phanto['danceability'], phanto['valence'], color = 'red', label = 'a')
stv_scatter = ax4.scatter(stv['danceability'], stv['valence'], color = 'gray', label = 'b') #, label = "St. Vincent")
ax4.set_xlabel('Danceability')
ax4.set_ylabel('Valence')
ax4.set_title('Phantogram and St. Vincenet: Danceability by Valence')
ax4.legend(['Phantogram = red', 'St. Vincent = grey'])
fig4.suptitle('Something')

plt.style.use('grayscale')

plt.legend(handles = [phanto_scatter, stv_scatter])
plt.show()


# plt.xlabel('Something')
# plt.title('Something')

# %%
# phanto = ad[ad['artist-album'] == 'Phantogram: Memory of A Day']
# stv = ad[ad['artist-album'] == 'St. Vincent: All Born Screaming']


fig4, ax4 = plt.subplots()
# phanto_scatter = ax4.scatter(phanto['danceability'], phanto['valence'], color = 'red', label = 'a')
# stv_scatter = ax4.scatter(stv['danceability'], stv['valence'], color = 'gray', label = 'b') #, label = "St. Vincent")
ax4.scatter(ad['danceability'], ad['valence'], edgecolors = ['red', 'grey']) 
ax4.set_xlabel('Danceability')
ax4.set_ylabel('Valence')
ax4.set_title('Phantogram and St. Vincenet: Danceability by Valence')
# ax4.legend(['Phantogram = red', 'St. Vincent = grey'])
fig4.suptitle('Something')

# plt.legend(handles = [phanto_scatter, stv_scatter])
plt.show()


# plt.xlabel('Something')
# plt.title('Something')
