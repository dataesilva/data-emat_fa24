# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5C4E-F292
#
#  Directory of c:\Users\dsilv\data-emat_fa24
#
# 10/24/2024  10:05 AM    <DIR>          .
# 10/23/2024  05:11 PM    <DIR>          ..
# 09/24/2024  09:41 AM    <DIR>          .ipynb_checkpoints
# 10/24/2024  10:05 AM            56,715 analysis_prep.ipynb
# 10/24/2024  10:04 AM            43,790 audio-features-analysis.csv
# 10/24/2024  10:11 AM           129,882 bivariate-plots_prep.ipynb
# 11/01/2022  09:36 AM            77,889 cces_example_data.csv
# 09/17/2024  08:59 AM            23,568 IG-comment-tidy-example.ipynb
# 10/24/2024  09:40 AM    <DIR>          in-class-demonstrations
# 08/19/2024  04:21 PM            17,098 LICENSE
# 08/26/2024  05:05 PM    <DIR>          markdown-image-examples
# 10/15/2024  09:40 AM            36,518 merge_prep.ipynb
# 08/19/2024  04:21 PM                95 README.md
# 10/17/2024  10:21 AM            72,334 recode-replace_prep.ipynb
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
audio_features = pd.read_csv('audio-features-analysis.csv')
audio_features.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.188   0.489    2   -10.152     1       0.0378
# 1           1         0.258   0.307    7   -10.207     1       0.0688
# 2           2         0.770   0.736    8    -4.980     0       0.0569
# 3           3         0.483   0.764    9    -4.897     1       0.0453
# 4           4         0.761   0.854   11    -3.405     0       0.0521
#
#    acousticness  instrumentalness  liveness  ...  \
# 0       0.76100           0.10300     0.109  ...
# 1       0.13000           0.00291     0.102  ...
# 2       0.06210           0.00843     0.109  ...
# 3       0.03800           0.13700     0.350  ...
# 4       0.00438           0.00615     0.315  ...
#
#                                                 href  is_local is_playable  \
# 0  https://api.spotify.com/v1/tracks/5tuHiLI7CPV1...     False        True
# 1  https://api.spotify.com/v1/tracks/5iI1svWkerLI...     False        True
# ...

# %%
audio_features.columns
# Out:
# Index(['Unnamed: 0', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type_x', 'id', 'uri_x', 'track_href',
#        'analysis_url', 'duration_ms_x', 'time_signature', 'album', 'artists',
#        'disc_number', 'duration_ms_y', 'explicit', 'external_ids',
#        'external_urls', 'href', 'is_local', 'is_playable', 'name',
#        'popularity', 'preview_url', 'track_number', 'type_y', 'uri_y',
#        'artist-album'],
#       dtype='object')

# %%
fig1, ax1 = plt.subplots(1, 2, figsize = (7, 5))
ax1[0].hist(audio_features['valence'])
ax1[1].hist(audio_features['danceability'])

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(x = audio_features['danceability'],
            y = audio_features['valence'])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(x = audio_features['energy'],
            y = audio_features['instrumentalness'], alpha = .5)

plt.show()

# %%
fig4, ax4 = plt.subplots()
ax4.scatter(x = audio_features['energy'],
            y = audio_features['loudness'], alpha = .5)

plt.show()

# %%
audio_features[audio_features['artist-album'] != 'St. Vincent: All Born Screaming']
# Out:
#     Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 10           0         0.408   0.928    6    -5.208     0       0.0568
# 11           1         0.503   0.757    0    -6.163     1       0.0521
# 12           2         0.293   0.664    2    -6.427     1       0.0309
# 13           3         0.688   0.793    2    -5.031     1       0.0392
# 14           4         0.520   0.782    5    -8.134     0       0.0457
# 15           5         0.582   0.743    2    -6.728     1       0.0443
# 16           6         0.520   0.464    7    -6.578     1       0.0264
# 17           7         0.496   0.676    0    -7.440     1       0.0332
# 18           8         0.502   0.808    2    -5.494     0       0.0316
# 19           9         0.445   0.754    4    -5.052     0       0.0463
# 20          10         0.568   0.812    2    -4.801     1       0.0394
# 21          11         0.396   0.546    4    -8.655     1       0.0268
#
# ...

# %%
mid_df = audio_features[audio_features['artist-album'] == 'St. Vincent: All Born Screaming']
lon_df = audio_features[audio_features['artist-album'] == 'Phantogram: Memory of A Day']
fig5, ax5 = plt.subplots()
ax5.scatter(x = mid_df['instrumentalness'],
            y = mid_df['danceability'],
            label = 'St. Vincent',
           color = 'red',
           marker = 'd',
           alpha = .5)
ax5.scatter(x = lon_df['instrumentalness'],
            y = lon_df['danceability'],
            label = 'Phantogram',
           color = 'green',
           marker = 's',
           alpha = .5)

ax5.set_title('Relationship between\nDanceability and Valence for Two 2022 Pop Albums')
ax5.set_xlabel('Instrumentalness')
ax5.set_ylabel('Danceability')
ax5.legend()
plt.show()
