# %%
import pandas as pd
import requests
from io import StringIO
import json

# %% [markdown]
# Site to check out later with public APIs: https://github.com/public-apis/public-apis?tab=readme-ov-file

# %%
url = "https://en.wikipedia.org/wiki/List_of_Triumph_motorcycles"

# %%
response_wiki = requests.get(url)
response_wiki.status_code
# Out:
# 200

# %%
response_wiki.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of Triumph motorcycles - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disab
# ...

# %%
table_list = pd.read_html(StringIO(response_wiki.text))

# %%
table_list[2].head()
# Out:
#                 0                          1                2  \
# 0           Model  Engine displacement [cm3]  Production time
# 1     First model                        NaN        1902-1904
# 2    Second Model                        NaN             1905
# 3           Model                        474        1908-1909
# 4  Model Roadster                        500        1910-1913
#
#                                                    3
# 0                                              Notes
# 1               used Minerva, JAP and Fafnir engines
# 2  Triumph used their own engine for the first ti...
# 3                      production up to 3000 in 1909
# 4  single speed, optional rear hub clutch as the ...

# %%
table_list[2].rename(columns=table_list[2].iloc[0]).drop(axis = 1, index = 0)
# Out:
#                                 Model Engine displacement [cm3]  \
# 1                         First model                       NaN
# 2                        Second Model                       NaN
# 3                               Model                       474
# 4                      Model Roadster                       500
# 5                             Model C                       550
# 6                            Model TT                       500
# 7                             Model H                       550
# 8                            Model SD                       550
# 9                             Model R                       500
# 10                            Model P                       500
# 11                            Model N                       500
# 12                            Model X               150 and 175
# 13                           Model WO                       250
# 14                                 XO                       150
# ...

# %%
prewar_df = table_list[2].rename(columns=table_list[2].iloc[0]).drop(axis = 1, index = 0)
prewar_df['Era'] = 'Pre War'
prewar_df.head()
# Out:
#             Model Engine displacement [cm3] Production time  \
# 1     First model                       NaN       1902-1904
# 2    Second Model                       NaN            1905
# 3           Model                       474       1908-1909
# 4  Model Roadster                       500       1910-1913
# 5         Model C                       550       1913-1914
#
#                                                Notes      Era
# 1               used Minerva, JAP and Fafnir engines  Pre War
# 2  Triumph used their own engine for the first ti...  Pre War
# 3                      production up to 3000 in 1909  Pre War
# 4  single speed, optional rear hub clutch as the ...  Pre War
# 5          Three speed Sturmey Archer rear wheel hub  Pre War

# %%
table_list[3].head()
# Out:
#                                0                          1                2  \
# 0                          Model  Engine displacement [cm3]  Production time
# 1  Triumph Grand Prix 500 cc OHV                        500        1947–1949
# 2                     TR5 Trophy                        500        1949–1958
# 3                 Triumph TRW500                        500        1950–1964
# 4                 6T Thunderbird                        650              NaN
#
#                                                    3    4
# 0                                              Notes  NaN
# 1  Used an all alloy stationary engine, designed ...  NaN
# 2  Competition bike winner of ISDT Trophy for 4 y...  NaN
# 3          Side valve military production motorcycle  NaN
# 4                                               twin  NaN

# %%
key = pd.read_csv(r"C:\Users\dsilv\Dropbox\Kent\APIKey-BallDontLie.txt")

# %%
header = {'Authorization': str(key['APIKey-BallDontLie'].iloc[0])}

# %%
response2 = requests.get('https://api.balldontlie.io/v1/players?search=david', headers = header)
response2.status_code
# Out:
# 200

# %%
player_dict = json.loads(response2.text)
player_dict.keys()
# Out:
# dict_keys(['data', 'meta'])

# %%
# player_dict['data']

# %%
pd.DataFrame(player_dict['data'])
# Out:
#       id first_name   last_name position height weight jersey_number  \
# 0    350      David       Nwaba        G    6-5    219             2
# 1    633      David        Wood             6-9    230             7
# 2    658      David      Benoit             6-8    220            21
# 3    705      David      Rivers             6-0    170            32
# 4    857      David      Wesley             6-1    203             4
# 5    984      David      Vaughn             6-9    240            42
# 6   1188     Kornel       David             6-9    230             9
# 7   1334      David  Vanterpool             6-5    200            22
# 8   1481      David        West             6-9    250             3
# 9   1554      David    Harrison             7-0    280            13
# 10  1641      David         Lee             6-9    245            10
# 11  1681      David        Noel             6-6    230            34
# 12  1759   Jermareo    Davidson            6-10    230            33
# ...
